# %% [markdown]
# # PHP 2021

# %% [markdown]
# ## 10. Laravel TDD

# %% [markdown]
# Tasks:
#
# - Add new model for book review (model ```Review```, table ```reviews```)
# - Define 1:N relationship between books and reviews
# - Add controller for nested resource (reviews under a book)
# - Controller should support CRUD (create, read, update, and delete) operations
# - Add acceptance tests for new functionality

# %% [markdown]
# Resources:
#
# - [Migrations: Foreign Key Constraints](https://laravel.com/docs/8.x/migrations#foreign-key-constraints)
# - [Eloquent: Relationships - One To Many](https://laravel.com/docs/8.x/eloquent-relationships#one-to-many)
# - [Eloquent: Relationships - One To Many (Inverse) / Belongs To](https://laravel.com/docs/8.x/eloquent-relationships#one-to-many-inverse)
# - [Controllers: Nested Resources](https://laravel.com/docs/8.x/controllers#restful-nested-resources)

# %% [markdown]
# Start database:

# %%
! sudo docker run --name=mysql --net=host --rm --env MYSQL_ROOT_PASSWORD=root123 --env MYSQL_ROOT_HOST=% --env MYSQL_DATABASE=test --env MYSQL_USER=test --env MYSQL_PASSWORD=test123 -d mysql/mysql-server:8.0
# Out:
# 0c5b5940e6c85544a6cf16df493ed830c5d457c2aec5b2a34ba04d1ec143fd20

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306" 2> /dev/null; do sleep 1; done; echo "Done.";
# Out:
# Done.

# %% [markdown]
# Edit the code:

# %%
! phpstorm project
# Out:
# (java:1062): dbind-WARNING **: 15:41:20.742: Couldn't connect to accessibility bus: Failed to connect to socket /tmp/dbus-DOYULCjtix: No such file or directory
# 2022-01-15 15:41:26,982 [   6615]   WARN - l.NotificationGroupManagerImpl - Notification group CodeWithMe is already registered (group=com.intellij.notification.NotificationGroup@4882ff44). Plugin descriptor: PluginDescriptor(name=Code With Me, id=com.jetbrains.codeWithMe, descriptorPath=plugin.xml, path=/opt/PhpStorm-212.5080.71/plugins/cwm-plugin, version=212.5080.71, package=null)
# 2022-01-15 15:41:27,641 [   7274]  ERROR - nSystem.impl.ActionManagerImpl - Assertion failed
# java.lang.Throwable: Assertion failed
# 	at com.intellij.openapi.diagnostic.Logger.assertTrue(Logger.java:218)
# 	at com.intellij.openapi.diagnostic.Logger.assertTrue(Logger.java:227)
# 	at com.intellij.openapi.actionSystem.impl.ActionManagerImpl.<init>(ActionManagerImpl.java:139)
# ...

# %%
! ls
# Out:
# bitbucket-pipelines.yml  db_run.sh  index.ipynb  mysz.jpg  php.env  project

# %% [markdown]
# You can test your solution using included tests:

# %%
# %cd project
# Out:
# /home/student/portfello/project

# %%
! composer install
# Out:
# Installing dependencies from lock file (including require-dev)
# Verifying lock file contents can be installed on current platform.
# Nothing to install, update or remove
# Package swiftmailer/swiftmailer is abandoned, you should avoid using it. Use symfony/mailer instead.
# Generating optimized autoload files
# > Illuminate\Foundation\ComposerScripts::postAutoloadDump
# > @php artisan package:discover --ansi
# Discovered Package: facade/ignition
# Discovered Package: fruitcake/laravel-cors
# Discovered Package: intervention/image
# Discovered Package: laravel/breeze
# Discovered Package: laravel/sail
# Discovered Package: laravel/sanctum
# Discovered Package: laravel/tinker
# Discovered Package: nesbot/carbon
# Discovered Package: nunomaduro/collision
# Package manifest generated successfully.
# 82 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!

# %%
! cp .env.example .env

# %%
! php artisan key:generate
# Out:
# Application key set successfully.

# %%
! php artisan migrate:fresh
# Out:
# Dropped all tables successfully.
# Migration table created successfully.
# Migrating: 2014_10_12_000000_create_users_table
# Migrated:  2014_10_12_000000_create_users_table (44.24ms)
# Migrating: 2014_10_12_100000_create_password_resets_table
# Migrated:  2014_10_12_100000_create_password_resets_table (34.95ms)
# Migrating: 2019_08_19_000000_create_failed_jobs_table
# Migrated:  2019_08_19_000000_create_failed_jobs_table (51.31ms)
# Migrating: 2019_12_14_000001_create_personal_access_tokens_table
# Migrated:  2019_12_14_000001_create_personal_access_tokens_table (88.63ms)
# Migrating: 2022_01_08_194834_create_groups_table
# Migrated:  2022_01_08_194834_create_groups_table (34.41ms)
# Migrating: 2022_01_08_195804_create_group_user_table
# Migrated:  2022_01_08_195804_create_group_user_table (141.23ms)
# Migrating: 2022_01_08_203000_create_expenses_table
# Migrated:  2022_01_08_203000_create_expenses_table (68.25ms)
# Migrating: 2022_01_08_210450_create_expenses_user_table
# ...

# %%
! php artisan db:seed
# Out:
# Database seeding completed successfully.

# %%
! mysqldump -h127.0.0.1 -u root --password=root123 test > tests_codeception/_data/dump.sql
# Out:
# mysqldump: [Warning] Using a password on the command line interface can be insecure.

# %%
! vendor/bin/phpunit
# Out:
# PHPUnit 9.5.11 by Sebastian Bergmann and contributors.
#
# ..F.....F......F.                                                 17 / 17 (100%)
#
# Time: 00:01.690, Memory: 42.50 MB
#
# There were 3 failures:
#
# 1) Tests\Feature\Auth\AuthenticationTest::test_users_can_authenticate_using_the_login_screen
# The user is not authenticated
# Failed asserting that false is true.
#
# /home/student/portfello/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/InteractsWithAuthentication.php:49
# /home/student/portfello/project/tests/Feature/Auth/AuthenticationTest.php:30
#
# 2) Tests\Feature\Auth\PasswordConfirmationTest::test_password_can_be_confirmed
# Session has unexpected errors:
#
# [
#     "The provided password is incorrect."
# ]
# Failed asserting that true is false.
#
# /home/student/portfello/project/vendor/laravel/framework/src/Illuminate/Testing/TestResponse.php:1340
# /home/student/portfello/project/tests/Feature/Auth/PasswordConfirmationTest.php:31
#
# ...

# %%
import subprocess
artisanServe = subprocess.Popen(['php', 'artisan', 'serve', '--port', '8888'])

# %%
! php vendor/bin/codecept generate:cept acceptance Reviews
# Out:
# Starting Laravel development server: http://127.0.0.1:8888
# Test ReviewsCept.php already exists

# %%
! php artisan make:model Review --factory
# Out:
# [Sat Jan 15 15:41:12 2022] PHP 8.0.10 Development Server (http://127.0.0.1:8888) started
# Model already exists!

# %%
! php artisan make:migration create_reviews_table
# Out:
#    InvalidArgumentException
#
#   A CreateReviewsTable class already exists.
#
#   at vendor/laravel/framework/src/Illuminate/Database/Migrations/MigrationCreator.php:102
#      98▕             }
#      99▕         }
#     100▕
#     101▕         if (class_exists($className = $this->getClassName($name))) {
#   ➜ 102▕             throw new InvalidArgumentException("A {$className} class already exists.");
#     103▕         }
#     104▕     }
#     105▕
#     106▕     /**
#
#       +16 vendor frames
#   17  artisan:37
#       Illuminate\Foundation\Console\Kernel::handle()

# %%
! vendor/bin/codecept run
# Out:
# Starting Laravel development server: http://127.0.0.1:8888
# [Mon Jan  3 13:22:42 2022] PHP 8.0.10 Development Server (http://127.0.0.1:8888) started
# Codeception PHP Testing Framework v4.1.22
# Powered by PHPUnit 9.5.10 by Sebastian Bergmann and contributors.
#
# Acceptance Tests (4) -----------------------------------------------------------
# - 01_HomepageCept: See Laravel links on homepage[Mon Jan  3 13:23:02 2022] 127.0.0.1:33318 Accepted
# [Mon Jan  3 13:23:03 2022] 127.0.0.1:33318 Closing
# ✔ 01_HomepageCept: See Laravel links on homepage (0.83s)
# ✔ 02_CommentsCept: See comments from DB displayed on page (0.48s)
# - 03_LoginCept: Login with existing user[Mon Jan  3 13:23:17 2022] 127.0.0.1:33322 Accepted
# [Mon Jan  3 13:23:17 2022] 127.0.0.1:33322 Closing
# [Mon Jan  3 13:23:17 2022] 127.0.0.1:33328 Accepted
# [Mon Jan  3 13:23:18 2022] 127.0.0.1:33328 Closing
# [Mon Jan  3 13:23:22 2022] 127.0.0.1:33334 Accepted
# [Mon Jan  3 13:23:22 2022] 127.0.0.1:33334 Closing
# ...

# %%
! killall php php8.0

# %%
# %cd ..
# Out:
# /home/student/portfello

# %% [markdown]
# Stop database:

# %%
! sudo docker container stop mysql
# Out:
# mysql
